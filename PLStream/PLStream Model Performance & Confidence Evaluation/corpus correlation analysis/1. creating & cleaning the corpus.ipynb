# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/arxiv/arxiv-metadata-oai-snapshot.json

# %% [markdown]
# **DATA LOADING**

# %% [markdown]
# **Installing essential libraries to load the ARXIV Kaggle dataset**

# %%
import numpy as np
import pandas as pd
import json
from collections import Counter

# %% [markdown]
# **Converting JSON file to CSV file**

# %%
#Get a list of dicts and convert into a pandas dataframe
arxiv_data = []
for line in open('/kaggle/input/arxiv/arxiv-metadata-oai-snapshot.json', 'r'):
    arxiv_data.append(json.loads(line))
df = pd.DataFrame.from_records(arxiv_data)

# %%
#Filter rows as required and save the resulting df for later use. Here I'm extracting records with arxiv papers having cs.CL as one of the categories.
drop_idx = []
for index, row in df.iterrows():
    if 'cs.CL' not in row['categories']:
        drop_idx.append(index)
df = df.drop(drop_idx).reset_index(drop=True)
df.to_csv('arxiv_cs-CL.csv', index=False)

# %%
df.sample(3)
# Out:
#                id       submitter  \
# 19667  2009.02554  Matthew Berger
# 15657  2001.03712     Geondo Park
# 8048   1806.07699    Vivian Silva
#
#                                                  authors  \
# 19667                                     Matthew Berger
# 15657  Geondo Park, Chihye Han, Wonjun Yoon, Daeshik Kim
# 8048   Vivian S. Silva, Andr\'e Freitas, Siegfried Ha...
#
#                                                    title  \
# 19667       Visually Analyzing Contextualized Embeddings
# 15657  MHSAN: Multi-Head Self-Attention Network for V...
# 8048   Word Tagging with Foundational Ontology Classe...
#
#                                                 comments  \
# 19667  IEEE Vis 2020, Observable notebook demo at\n  ...
# 15657  Accepted by the 2020 IEEE Winter Conference on...
# 8048          13 pages, 1 figure, presented at EKAW 2016
#
#                                              journal-ref  \
# 19667                                               None
# 15657                                               None
# 8048   Proceedings of the 20th International Conferen...
#
#                                 doi report-no         categories  \
# 19667                          None      None        cs.HC cs.CL
# 15657                          None      None  cs.CV cs.CL cs.LG
# 8048   10.1007/978-3-319-49004-5_38      None              cs.CL
#
#                                                  license  \
# 19667  http://arxiv.org/licenses/nonexclusive-distrib...
# 15657  http://arxiv.org/licenses/nonexclusive-distrib...
# 8048   http://arxiv.org/licenses/nonexclusive-distrib...
#
#                                                 abstract  \
# 19667    In this paper we introduce a method for visu...
# 15657    Visual-semantic embedding enables various ta...
# 8048     Semantic annotation is fundamental to deal w...
#
#                                                 versions update_date  \
# 19667  [{'version': 'v1', 'created': 'Sat, 5 Sep 2020...  2020-09-08
# 15657  [{'version': 'v1', 'created': 'Sat, 11 Jan 202...  2020-01-14
# 8048   [{'version': 'v1', 'created': 'Wed, 20 Jun 201...  2018-06-21
#
#                                           authors_parsed
# 19667                              [[Berger, Matthew, ]]
# 15657  [[Park, Geondo, ], [Han, Chihye, ], [Yoon, Won...
# 8048   [[Silva, Vivian S., ], [Freitas, André, ], [Ha...

# %% [markdown]
# **DATA WRANGLING & MANIPULATION**

# %%
for col in df.columns:
    print(col)
# Out:
# id
# submitter
# authors
# title
# comments
# journal-ref
# doi
# report-no
# categories
# license
# abstract
# versions
# update_date
# authors_parsed

# %% [markdown]
# **Dropping unnecessary columns**

# %%
new_df = df[['title', 'abstract', 'update_date']]
new_df.head(5)
# Out:
#                                                title  \
# 0  Introduction to Arabic Speech Recognition Usin...
# 1  Arabic Speech Recognition System using CMU-Sph...
# 2  An Automated Evaluation Metric for Chinese Tex...
# 3  On the Development of Text Input Method - Less...
# 4  Network statistics on early English Syntax: St...
#
#                                             abstract update_date
# 0    In this paper Arabic was investigated from t...  2007-05-23
# 1    In this paper we present the creation of an ...  2007-05-23
# 2    In this paper, we propose an automated evalu...  2013-10-29
# 3    Intelligent Input Methods (IM) are essential...  2007-05-23
# 4    This paper includes a reflection on the role...  2007-05-23

# %% [markdown]
# **Extracting years from update_date**

# %%
new_df['years'] = new_df['update_date'].str[:4]
new_df.head(5)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                title  \
# 0  Introduction to Arabic Speech Recognition Usin...
# 1  Arabic Speech Recognition System using CMU-Sph...
# 2  An Automated Evaluation Metric for Chinese Tex...
# 3  On the Development of Text Input Method - Less...
# 4  Network statistics on early English Syntax: St...
#
#                                             abstract update_date years
# 0    In this paper Arabic was investigated from t...  2007-05-23  2007
# 1    In this paper we present the creation of an ...  2007-05-23  2007
# 2    In this paper, we propose an automated evalu...  2013-10-29  2013
# 3    Intelligent Input Methods (IM) are essential...  2007-05-23  2007
# 4    This paper includes a reflection on the role...  2007-05-23  2007

# %%
new_df['years'].value_counts()
# Out:
# 2022    10735
# 2021     8144
# 2020     6684
# 2019     4911
# 2018     3453
# 2017     2207
# 2016     1630
# 2008      727
# 2015      726
# 2007      637
# 2014      492
# 2013      293
# 2012      200
# 2009      132
# 2011      103
# 2010       78
# Name: years, dtype: int64

# %%
new_df['years'] = pd.to_numeric(new_df['years'])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Deleting unnecessary years**

# %%
index_year = new_df[(new_df['years'] >= 2007) & (new_df['years'] <= 2017)].index
new_df.drop(index_year, inplace=True)
new_df.head(5)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                  title  \
# 52   Valence extraction using EM selection and co-o...
# 116  On the Vocabulary of Grammar-Based Codes and t...
# 126  The Latent Relation Mapping Engine: Algorithm ...
# 147  The Modular Audio Recognition Framework (MARF)...
# 246  Les entit\'es spatiales dans la langue : \'etu...
#
#                                               abstract update_date  years
# 52     This paper discusses two new procedures for ...  2020-03-11   2020
# 116    The article presents a new interpretation fo...  2020-03-11   2020
# 126    Many AI researchers and cognitive scientists...  2020-08-20   2020
# 147    MARF is an open-source research platform and...  2019-08-14   2019
# 246    While previous linguistic and psycholinguist...  2020-07-17   2020

# %% [markdown]
# **Checking...**

# %%
new_df['years'].value_counts()
# Out:
# 2022    10735
# 2021     8144
# 2020     6684
# 2019     4911
# 2018     3453
# Name: years, dtype: int64

# %%
new_df = new_df.drop(['update_date'], axis=1)

# %%
new_df.head(5)
# Out:
#                                                  title  \
# 52   Valence extraction using EM selection and co-o...
# 116  On the Vocabulary of Grammar-Based Codes and t...
# 126  The Latent Relation Mapping Engine: Algorithm ...
# 147  The Modular Audio Recognition Framework (MARF)...
# 246  Les entit\'es spatiales dans la langue : \'etu...
#
#                                               abstract  years
# 52     This paper discusses two new procedures for ...   2020
# 116    The article presents a new interpretation fo...   2020
# 126    Many AI researchers and cognitive scientists...   2020
# 147    MARF is an open-source research platform and...   2019
# 246    While previous linguistic and psycholinguist...   2020

# %%
new_df.dtypes
# Out:
# title       object
# abstract    object
# years        int64
# dtype: object

# %% [markdown]
# **Converting object datatype of dataframe columns to string**

# %%
new_df['title'] = new_df['title'].astype("string")
new_df['abstract'] = new_df['abstract'].astype("string")

# %% [markdown]
# **Checking...**

# %%
new_df.dtypes
# Out:
# title       string
# abstract    string
# years        int64
# dtype: object

# %% [markdown]
# **Combining title+abstract texts for corpus creation**

# %%
new_df['text'] = new_df['title'].astype(str) +" "+ new_df['abstract'].astype(str)

# %%
new_df.head(5)
# Out:
#                                                  title  \
# 52   Valence extraction using EM selection and co-o...
# 116  On the Vocabulary of Grammar-Based Codes and t...
# 126  The Latent Relation Mapping Engine: Algorithm ...
# 147  The Modular Audio Recognition Framework (MARF)...
# 246  Les entit\'es spatiales dans la langue : \'etu...
#
#                                               abstract  years  \
# 52     This paper discusses two new procedures for ...   2020
# 116    The article presents a new interpretation fo...   2020
# 126    Many AI researchers and cognitive scientists...   2020
# 147    MARF is an open-source research platform and...   2019
# 246    While previous linguistic and psycholinguist...   2020
#
#                                                   text
# 52   Valence extraction using EM selection and co-o...
# 116  On the Vocabulary of Grammar-Based Codes and t...
# 126  The Latent Relation Mapping Engine: Algorithm ...
# 147  The Modular Audio Recognition Framework (MARF)...
# 246  Les entit\'es spatiales dans la langue : \'etu...

# %%
new_df = new_df.drop(['title', 'abstract'], axis=1)
new_df.head(5)
# Out:
#      years                                               text
# 52    2020  Valence extraction using EM selection and co-o...
# 116   2020  On the Vocabulary of Grammar-Based Codes and t...
# 126   2020  The Latent Relation Mapping Engine: Algorithm ...
# 147   2019  The Modular Audio Recognition Framework (MARF)...
# 246   2020  Les entit\'es spatiales dans la langue : \'etu...

# %% [markdown]
# **CORPUS PRE-PROCESSING**

# %% [markdown]
# **STEP 1: Punctuation removal**

# %%
import string
string.punctuation

#function that removes punctuations
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

new_df['text']= new_df['text'].apply(lambda x:remove_punctuation(x))
new_df.head(5)
# Out:
#      years                                               text
# 52    2020  Valence extraction using EM selection and cooc...
# 116   2020  On the Vocabulary of GrammarBased Codes and th...
# 126   2020  The Latent Relation Mapping Engine Algorithm a...
# 147   2019  The Modular Audio Recognition Framework MARF a...
# 246   2020  Les entites spatiales dans la langue  etude de...

# %% [markdown]
# **STEP 2: Converting all text into lower-case characters**

# %%
new_df['text'] = new_df['text'].apply(lambda x: x.lower())
new_df.head(5)
# Out:
#      years                                               text
# 52    2020  valence extraction using em selection and cooc...
# 116   2020  on the vocabulary of grammarbased codes and th...
# 126   2020  the latent relation mapping engine algorithm a...
# 147   2019  the modular audio recognition framework marf a...
# 246   2020  les entites spatiales dans la langue  etude de...

# %%
new_df.to_csv('corpus.csv')
